# %% [markdown]
# Spark & PySpark
#
# ![image.png](attachment:63fccd98-0b27-40e9-832c-226c4b88b6de.png)
#
# SQL -> Processamento de dados estruturados, abstrai as estruturas de diversas fontes através dos DataFrames
#
# Streaming -> Permite o streaming de dados com propriedades distribuídas e com tolerância a falhas
#
# MLib -> Biblioteca escalável para ambientes distribuídos para criação de pipelines de ML
#
# Spark Core -> Motor de execução do Spark. RDD (Resilient Distributed Dataset) e Processamento em memória

# %%
# !pip install requests
# Out:
# /bin/sh: 1: pip: not found
